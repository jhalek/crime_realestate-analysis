# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
# Create reference to CSV file
csv_path = "resorce/Elyria_Police_Department.csv"

# Import the CSV into a pandas DataFrame
Elyria_df = pd.read_csv(csv_path, low_memory=False)
Elyria_df.head()
# Out:
#    incident_id        case_number       incident_datetime  \
# 0    100014928  2012-00003962-001  02/17/2012 12:00:00 AM
# 1    100014931  2012-00003991-001  02/17/2012 12:00:00 AM
# 2    100014932  2012-00003983-001  02/17/2012 12:00:00 AM
# 3    100056920  2012-00004037-001  02/18/2012 12:00:00 AM
# 4    100056921  2012-00004053-001  02/18/2012 12:00:00 AM
#
#   incident_type_primary                               incident_description  \
# 0   Breaking & Entering  Occured Date/Time(24hr): 02/17/2012 1357 - 02/...
# 1                 Theft  Occured Date/Time(24hr): 02/17/2012 1430 - 02/...
# 2    Theft from Vehicle  Occured Date/Time(24hr): 02/16/2012 2100 - 02/...
# 3        Property Crime  Occured Date/Time(24hr): 02/17/2012 2200 - 02/...
# 4                 Theft  Occured Date/Time(24hr): 02/18/2012 0430 - 02/...
#
#    clearance_type               address_1  address_2    city state    zip  \
# 0             NaN     300 Block FOURTH ST        NaN  ELYRIA    OH  44035
# ...

# %%
Elyria_df.columns
# Out:
# Index(['incident_id', 'case_number', 'incident_datetime',
#        'incident_type_primary', 'incident_description', 'clearance_type',
#        'address_1', 'address_2', 'city', 'state', 'zip', 'country', 'latitude',
#        'longitude', 'created_at', 'updated_at', 'location', 'hour_of_day',
#        'day_of_week', 'parent_incident_type'],
#       dtype='object')

# %%
# Create reference to CSV file
csv_path = "resorce/Lakewood_Police_Department.csv"

# Import the CSV into a pandas DataFrame
Lakewood_df = pd.read_csv(csv_path, low_memory=False)
#Lakewood_df.head()

# %%
Lakewood_df.columns
# Out:
# Index(['incident_id', 'case_number', 'incident_datetime',
#        'incident_type_primary', 'incident_description', 'clearance_type',
#        'address_1', 'address_2', 'city', 'state', 'zip', 'country', 'latitude',
#        'longitude', 'created_at', 'updated_at', 'location', 'hour_of_day',
#        'day_of_week', 'parent_incident_type',
#        'Lakewood Police Department Wards Shapes - 894r-etgh',
#        'Lakewood Police Department Districts Shapes - 4awj-stxn',
#        'Lakewood Police Department Beats Shapes - 7ytd-tryn'],
#       dtype='object')

# %%
Lakewood_df1= Lakewood_df[['incident_id', 'case_number', 'incident_datetime',
       'incident_type_primary', 'incident_description', 'clearance_type',
       'address_1', 'address_2', 'city', 'state', 'zip', 'country', 'latitude',
       'longitude', 'created_at', 'updated_at', 'location', 'hour_of_day',
       'day_of_week', 'parent_incident_type']]
Lakewood_df1
# Out:
#        incident_id  case_number       incident_datetime  \
# 0        758749062    116002459  05/05/2016 08:15:00 AM
# 1        759040382    161300049  05/09/2016 11:22:36 AM
# 2        759058353    161300088  05/09/2016 03:50:49 PM
# 3        771107142    116005222  06/05/2016 02:00:00 PM
# 4        764549226    161930005  07/11/2016 12:30:26 AM
# 5        770900167    116005174  09/02/2016 02:55:00 PM
# 6        771181375    116005240  09/06/2016 04:51:00 PM
# 7        765245894    116004051  03/01/2016 12:00:00 PM
# 8        760047994    161410035  05/20/2016 08:37:08 AM
# 9        763754949    116003681  07/01/2016 04:30:00 AM
# 10       763772779    116003690  07/01/2016 01:20:00 PM
# 11       763772776    116003691  07/01/2016 01:21:00 PM
# 12       763785828    116003692  07/01/2016 02:34:00 PM
# 13       763785821    116003693  07/01/2016 02:38:00 PM
# 14       790345470    170220043  01/22/2017 10:13:07 AM
# 15       809391539    171660015  06/15/2017 04:09:45 AM
# ...

# %%
result = df1.append(df2).columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-812801c81ffd> in <module>
# ----> 1 result = df1.append(df2).columns
#
# NameError: name 'df1' is not defined

# %%
crime_data = Elyria_df.append(Lakewood_df1)
crime_data.head()
# Out:
#    incident_id        case_number       incident_datetime  \
# 0    100014928  2012-00003962-001  02/17/2012 12:00:00 AM
# 1    100014931  2012-00003991-001  02/17/2012 12:00:00 AM
# 2    100014932  2012-00003983-001  02/17/2012 12:00:00 AM
# 3    100056920  2012-00004037-001  02/18/2012 12:00:00 AM
# 4    100056921  2012-00004053-001  02/18/2012 12:00:00 AM
#
#   incident_type_primary                               incident_description  \
# 0   Breaking & Entering  Occured Date/Time(24hr): 02/17/2012 1357 - 02/...
# 1                 Theft  Occured Date/Time(24hr): 02/17/2012 1430 - 02/...
# 2    Theft from Vehicle  Occured Date/Time(24hr): 02/16/2012 2100 - 02/...
# 3        Property Crime  Occured Date/Time(24hr): 02/17/2012 2200 - 02/...
# 4                 Theft  Occured Date/Time(24hr): 02/18/2012 0430 - 02/...
#
#    clearance_type               address_1  address_2    city state    zip  \
# 0             NaN     300 Block FOURTH ST        NaN  ELYRIA    OH  44035
# ...

# %%
crime_data.count()
# Out:
# incident_id              112111
# case_number              112111
# incident_datetime        111963
# incident_type_primary    112111
# incident_description     112111
# clearance_type                0
# address_1                112017
# address_2                     0
# city                     111970
# state                    112111
# zip                       90480
# country                   18275
# latitude                 112110
# longitude                112110
# created_at               111867
# updated_at               112111
# location                 111999
# hour_of_day              112111
# day_of_week              111963
# parent_incident_type     112111
# dtype: int64

# %%
Lakewood_df1= Lakewood_df[['incident_id', 'case_number', 'incident_datetime',
       'incident_type_primary', 'incident_description', 
       'address_1', 'city', 'state', 'zip', 'country', 'latitude',
       'longitude', 'created_at', 'updated_at', 'location', 'hour_of_day',
       'day_of_week', 'parent_incident_type']]

# %%
crime_data_df = crime_data.dropna(how='any')
crime_data_df.head()
# Out:
# Empty DataFrame
# Columns: [incident_id, case_number, incident_datetime, incident_type_primary, incident_description, clearance_type, address_1, address_2, city, state, zip, country, latitude, longitude, created_at, updated_at, location, hour_of_day, day_of_week, parent_incident_type]
# Index: []
